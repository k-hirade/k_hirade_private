# %%
import numpy as np
import matplotlib.pyplot as plot
import tensorflow as tf
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 85

# %%
#  検証用データを一時的に読み込み訓練
npz = np.load('Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.feat)
train_targets = npz['inputs'].astype(np.feat)

# 検証用データを一時的に読み込み
npz = np.load('Audiobooks_data_validation.npz')
# 訓練用のデータを入力とターゲットに分けて変数に代入
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# テストデータを一時的に読み込み
npz = np.load('Audiobooks_data_test.npz')
# テスト用のデータを入力とターゲットに分けて変数に代入
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 87
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/4225855434.py", line 4, in <module>
#     train_inputs = npz['inputs'].astype(np.feat)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/numpy/__init__.py", line 314, in __getattr__
#     "{!r}".format(__name__, attr))
# AttributeError: module 'numpy' has no attribute 'feat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/4225855434.py", line 4, in <module>
#     train_inputs = npz['inputs'].astype(np.feat)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/numpy/__init__.py", line 314, in __getattr__
#     "{!r}".format(__name__, attr))
# AttributeError: module 'numpy' has no attribute 'feat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/4225855434.py", line 4, in <module>
#     train_inputs = npz['inputs'].astype(np.feat)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/numpy/__init__.py", line 314, in __getattr__
#     "{!r}".format(__name__, attr))
# AttributeError: module 'numpy' has no attribute 'feat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
# 入力の数と出力の数を定義
input_size = 10
output_size = 2
# 隠れ層のユニットの数を定義
hidden_layer_size = 50
    
# モデルを作成
model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1番目の隠れ層
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2番目の隠れ層
    tf.keras.layers.Dense(output_size, activation='softmax') # 出力層
])


# 損失関数と最適化アルゴリズムを定義
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

### 訓練

# バッチサイズの設定
batch_size = 100

# 繰り返し回数の設定
max_epochs = 100

# アーリーストッピングの設定(patience->2回までなら損失関数がふえてok)
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

# モデルにデータを挿入
model.fit(train_inputs, # 訓練データの入力
          train_targets, # 訓練データのターゲット
          batch_size=batch_size, # バッチサイズ
          epochs=max_epochs, # 繰り返し回数
          callbacks=[early_stopping], # アーリーストッピング
          validation_data=(validation_inputs, validation_targets), # 検証データの指定
          verbose = 2 # 結果の見た目を変更
          )
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 88
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/1380709951.py", line 30, in <module>
#     model.fit(train_inputs, # 訓練データの入力
# NameError: name 'train_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/1380709951.py", line 30, in <module>
#     model.fit(train_inputs, # 訓練データの入力
# NameError: name 'train_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/1380709951.py", line 30, in <module>
#     model.fit(train_inputs, # 訓練データの入力
# NameError: name 'train_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique inTraceback (most recent call last):
#  database. History logging moved to new session 89
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/3029335762.py", line 1, in <module>
#     test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# NameError: name 'test_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/3029335762.py", line 1, in <module>
#     test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# NameError: name 'test_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/3029335762.py", line 1, in <module>
#     test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# NameError: name 'test_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique inTraceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/1320733958.py", line 1, in <module>
#     print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# NameError: name 'test_loss' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
#  database. History logging moved to new session 90
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/1320733958.py", line 1, in <module>
#     print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# NameError: name 'test_loss' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7_/5ly65s3j46zcgtgg9r0sjm940000gn/T/ipykernel_87487/1320733958.py", line 1, in <module>
#     print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# NameError: name 'test_loss' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/hiradekeishi/opt/anaconda3/envs/py3-TF2.0/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
